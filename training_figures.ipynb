# %% [markdown]
# # Looking at the best models' output

# %% [markdown]
# ## Let's examine the training logs

# %%
import pandas as pd
import numpy as np
import catboost
import torch

import helpers as hlp
import hyppars as pr
from pandas_ml import confusion_matrix

from os.path import join
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
logs_cat = pd.read_csv(join(hlp.path_logs, 'cat_eval.csv'), index_col=0)
logs_cat.plot()

# %% [markdown]
# ...there still are very slight improvements on the test set even on the latest couple of iterations
#
# Probably overfits, but my regularization was too harsh. Decreasing the number of boosters makes the model worse on the LB, too.
# So I went with the NN

# %%
logs_nn_tr = pd.read_csv(join(hlp.path_logs, 'nn_train.csv'), index_col=0)
logs_nn_te = pd.read_csv(join(hlp.path_logs, 'nn_test.csv'), index_col=0)

# %%
logs_nn = pd.concat({'train f1': logs_nn_tr['f1'], 'test f1': logs_nn_te['f1']}, axis=1)
logs_nn.plot()

# %% [markdown]
# Looks better! Might use some tuning or regularization, too, though
